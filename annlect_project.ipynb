# %% [markdown]
# <a href="https://colab.research.google.com/github/him863/Campaign-Data-Analysis/blob/main/annlect_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('/content/Campaign data.xlsx', sheet_name='Table 1')

# %%
df1.head()
# Out:
#         Date Data source          Campaign Media Type  \
# 0 2019-12-30   Pinterest  Kicks campaign 2    Display
# 1 2019-12-30   Pinterest  Kicks campaign 2    Display
# 2 2019-12-30   Pinterest  Kicks campaign 2    Display
# 3 2019-12-30   Pinterest  Kicks campaign 2    Display
# 4 2019-12-30   Pinterest  Kicks campaign 2    Display
#
#                        City       Metric  Value
# 0   Colorado Springs-Pueblo  Impressions    1.0
# 1   Colorado Springs-Pueblo   Media Cost    0.0
# 2   Colorado Springs-Pueblo       Clicks    0.0
# 3  Sacramnto-Stkton-Modesto  Impressions    1.0
# 4  Sacramnto-Stkton-Modesto   Media Cost    0.0

# %%
df2= pd.read_excel('/content/Campaign data.xlsx', sheet_name='Table 2')

# %%
df2.head()
# Out:
#             Campaign   Message type   Model
# 0  Sentra campaign 2  Future Market  Sentra
# 1  Sentra campaign 4  Future Market  Sentra
# 2  Sentra campaign 3  Future Market  Sentra
# 3  Sentra campaign 1  Future Market  Sentra
# 4  Altima campaign 1  Future Market  Altima

# %% [markdown]
# # top 5 month in terms of impression

# %%
df1['Date']= pd.to_datetime(df1['Date'])

# %%
df1['Month']= df1['Date'].dt.month

# %%
df1.head()
# Out:
#         Date Data source          Campaign Media Type  \
# 0 2019-12-30   Pinterest  Kicks campaign 2    Display
# 1 2019-12-30   Pinterest  Kicks campaign 2    Display
# 2 2019-12-30   Pinterest  Kicks campaign 2    Display
# 3 2019-12-30   Pinterest  Kicks campaign 2    Display
# 4 2019-12-30   Pinterest  Kicks campaign 2    Display
#
#                        City       Metric  Value  Month
# 0   Colorado Springs-Pueblo  Impressions    1.0     12
# 1   Colorado Springs-Pueblo   Media Cost    0.0     12
# 2   Colorado Springs-Pueblo       Clicks    0.0     12
# 3  Sacramnto-Stkton-Modesto  Impressions    1.0     12
# 4  Sacramnto-Stkton-Modesto   Media Cost    0.0     12

# %%
impressions_by_month = df1[df1['Metric']=='Impressions'].groupby('Month')['Value'].sum().reset_index()

# %%
top_5_months = impressions_by_month.sort_values(by = 'Value', ascending= False).head(5)
top_5_months
# Out:
#    Month        Value
# 8      9  195438584.0
# 2      3  159653850.0
# 9     10  129386691.0
# 7      8  117299580.0
# 1      2   95672149.0

# %% [markdown]
# # which model has max impression

# %%
# inner join trying
df_merge = pd.merge(df1, df2,how= 'inner', on = 'Campaign')
df_merge.head(2)
# Out:
#         Date Data source          Campaign Media Type  \
# 0 2019-12-30   Pinterest  Kicks campaign 2    Display
# 1 2019-12-30   Pinterest  Kicks campaign 2    Display
#
#                       City       Metric  Value  Month Message type  Model
# 0  Colorado Springs-Pueblo  Impressions    1.0     12  Near Market  Kicks
# 1  Colorado Springs-Pueblo   Media Cost    0.0     12  Near Market  Kicks

# %%
df_merge[df_merge['Metric']== 'Impressions'].groupby('Model')['Value'].sum().sort_values(ascending= False)
# Out:
# Model
# Pathfinder     275832034.0
# Armada         175569709.0
# Rogue          132109157.0
# Altima          99823376.0
# Kicks           95929225.0
# Sentra          64176011.0
# Multi-Model      9135991.0
# Name: Value, dtype: float64

# %% [markdown]
# Model: Pathfinder   275832034.0

# %% [markdown]
# # top 3 campaigns in terms of impressions for every messege type

# %%
impressions_df = df_merge[df_merge['Metric'] == 'Impressions']
impressions_df.head(2)
# Out:
#         Date Data source          Campaign Media Type  \
# 0 2019-12-30   Pinterest  Kicks campaign 2    Display
# 3 2019-12-30   Pinterest  Kicks campaign 2    Display
#
#                        City       Metric  Value  Month Message type  Model
# 0   Colorado Springs-Pueblo  Impressions    1.0     12  Near Market  Kicks
# 3  Sacramnto-Stkton-Modesto  Impressions    1.0     12  Near Market  Kicks

# %%
top_3_near_market= impressions_df[impressions_df['Message type']=='Near Market'].groupby('Campaign')['Value'].sum().sort_values( ascending=False).head(3)
top_3_near_market
# Out:
# Campaign
# Armada campaign 2        118817195.0
# Pathfinder campaign 2    115286607.0
# Pathfinder campaign 6     51823574.0
# Name: Value, dtype: float64

# %%
top_3_future_market= impressions_df[impressions_df['Message type']=='Future Market'].groupby('Campaign')['Value'].sum().sort_values( ascending=False).head(3)
top_3_future_market
# Out:
# Campaign
# Altima campaign 3    45451489.0
# Altima campaign 1    35863660.0
# Kicks campaign 4     33664998.0
# Name: Value, dtype: float64

# %% [markdown]
# # Campaign: max_impressions vs max_clicks

# %%
# for max_impressions campaign
impressions_df.groupby('Campaign')['Value'].sum().sort_values(ascending = False).head(1)
# Out:
# Campaign
# Armada campaign 2    118817195.0
# Name: Value, dtype: float64

# %%
# for max_clicks: campaign
df_clicks = impressions_df = df_merge[df_merge['Metric'] == 'Clicks']
df_clicks.head(2)
# Out:
#         Date Data source          Campaign Media Type  \
# 2 2019-12-30   Pinterest  Kicks campaign 2    Display
# 5 2019-12-30   Pinterest  Kicks campaign 2    Display
#
#                        City  Metric  Value  Month Message type  Model
# 2   Colorado Springs-Pueblo  Clicks    0.0     12  Near Market  Kicks
# 5  Sacramnto-Stkton-Modesto  Clicks    0.0     12  Near Market  Kicks

# %%
df_clicks.groupby('Campaign')['Value'].sum().sort_values(ascending = False).head(1)
# Out:
# Campaign
# Armada campaign 2    241938.0
# Name: Value, dtype: float64

# %% [markdown]
# so clearly 'NO'

# %% [markdown]
# # top 3 campaigns in terms of cpm( total media cost / total impressions *1000)

# %%
media_cost_df = df_merge[df_merge['Metric'] == 'Media Cost'].copy()
media_cost_df.head(2)
media_cost_df.rename(columns={'Value': 'media_cost'},inplace = True)
media_cost_df
media_cost_df.drop(columns=['Metric'], inplace=True)
media_cost_df
# Out:
#              Date Data source               Campaign    Media Type  \
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# 7      2020-01-06   Pinterest       Kicks campaign 2       Display
# 10     2020-01-06   Pinterest       Kicks campaign 2       Display
# 13     2020-01-06   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123685 2021-09-27   Pinterest  Pathfinder campaign 4  Online Video
# 123688 2021-09-27   Pinterest  Pathfinder campaign 4  Online Video
# 123691 2021-09-27   Pinterest  Pathfinder campaign 4  Online Video
# 123694 2021-09-27   Pinterest  Pathfinder campaign 4  Online Video
# 123697 2021-09-27   Pinterest  Pathfinder campaign 4  Online Video
#
#                               City  media_cost  Month Message type       Model
# 1          Colorado Springs-Pueblo        0.00     12  Near Market       Kicks
# ...

# %%
impressions_df = df_merge[df_merge['Metric'] == 'Impressions'].copy()
impressions_df.head(2)
impressions_df.rename(columns={'Value': 'impressions'},inplace = True)
impressions_df
impressions_df.drop(columns=['Metric'], inplace=True)
impressions_df
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 6      2020-01-06   Pinterest       Kicks campaign 2       Display
# 9      2020-01-06   Pinterest       Kicks campaign 2       Display
# 12     2020-01-06   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123684 2021-09-27   Pinterest  Pathfinder campaign 4  Online Video
# 123687 2021-09-27   Pinterest  Pathfinder campaign 4  Online Video
# 123690 2021-09-27   Pinterest  Pathfinder campaign 4  Online Video
# 123693 2021-09-27   Pinterest  Pathfinder campaign 4  Online Video
# 123696 2021-09-27   Pinterest  Pathfinder campaign 4  Online Video
#
#                               City  impressions  Month Message type  \
# 0          Colorado Springs-Pueblo          1.0     12  Near Market
# ...

# %%
cost_imp = pd.merge(media_cost_df, impressions_df, on = ['Date', 'Data source', 'Campaign', 'Media Type', 'City',
       'Month', 'Message type', 'Model'], how= 'inner')
cost_imp
df_media = cost_imp

# %%
cost_imp= cost_imp.groupby(['Campaign'])[['media_cost', 'impressions']].sum().reset_index()

# %%
cost_imp['cpm'] = (cost_imp['media_cost']/cost_imp['impressions'])*1000
#CPM.sort_values(ascending = False).head(3)
cost_imp.sort_values(by = 'cpm',).sort_values(by = 'cpm').head(3)
# Out:
#              Campaign  media_cost  impressions       cpm
# 13   Kicks campaign 2        0.00       1485.0  0.000000
# 12   Kicks campaign 1        0.00     120791.0  0.000000
# 43  Sentra campaign 2      719.29     193569.0  3.715936

# %% [markdown]
# # monthly avg cost for different media types

# %%
df1.head(2)
# Out:
#         Date Data source          Campaign Media Type  \
# 0 2019-12-30   Pinterest  Kicks campaign 2    Display
# 1 2019-12-30   Pinterest  Kicks campaign 2    Display
#
#                       City       Metric  Value  Month
# 0  Colorado Springs-Pueblo  Impressions    1.0     12
# 1  Colorado Springs-Pueblo   Media Cost    0.0     12

# %%
df3=df1[df1['Metric']=='Media Cost'].groupby(['Media Type', 'Month'])['Value'].mean().reset_index()
df3
# Out:
#       Media Type  Month       Value
# 0        Display      1    0.000000
# 1        Display      2  319.077112
# 2        Display      3  286.401385
# 3        Display      4   85.704674
# 4        Display      5    0.000000
# 5        Display      6    0.000000
# 6        Display      7    0.000000
# 7        Display      8    0.000000
# 8        Display      9  181.477207
# 9        Display     10    0.000925
# 10       Display     11    0.000000
# 11       Display     12    0.000000
# 12  Online Video      1  129.654865
# 13  Online Video      2  179.238458
# 14  Online Video      3  175.424714
# 15  Online Video      4  170.390385
# 16  Online Video      5    0.000000
# 17  Online Video      6    6.665146
# 18  Online Video      7   23.603320
# 19  Online Video      8  231.432863
# 20  Online Video      9  316.388868
# 21  Online Video     10  250.820020
# 22  Online Video     11  148.412704
# 23  Online Video     12  238.052949

# %% [markdown]
# # which media type is more expensive in terms of cpm ?

# %%
df_media
# Out:
#             Date Data source               Campaign    Media Type  \
# 0     2019-12-30   Pinterest       Kicks campaign 2       Display
# 1     2019-12-30   Pinterest       Kicks campaign 2       Display
# 2     2020-01-06   Pinterest       Kicks campaign 2       Display
# 3     2020-01-06   Pinterest       Kicks campaign 2       Display
# 4     2020-01-06   Pinterest       Kicks campaign 2       Display
# ...          ...         ...                    ...           ...
# 44072 2021-09-27   Pinterest  Pathfinder campaign 4  Online Video
# 44073 2021-09-27   Pinterest  Pathfinder campaign 4  Online Video
# 44074 2021-09-27   Pinterest  Pathfinder campaign 4  Online Video
# 44075 2021-09-27   Pinterest  Pathfinder campaign 4  Online Video
# 44076 2021-09-27   Pinterest  Pathfinder campaign 4  Online Video
#
#                              City  media_cost  Month Message type       Model  \
# 0         Colorado Springs-Pueblo        0.00     12  Near Market       Kicks
# ...

# %%
media_precpm= df_media.groupby('Media Type')[['media_cost', 'impressions']].sum().reset_index()
media_precpm
# Out:
#      Media Type  media_cost  impressions
# 0       Display  1527881.66  220536970.0
# 1  Online Video  6836809.63  674263903.0

# %%
media_precpm['cpm'] = (media_precpm['media_cost']/media_precpm['impressions'])*1000
media_precpm
# Out:
#      Media Type  media_cost  impressions  cpm_media        cpm
# 0       Display  1527881.66  220536970.0   6.928007   6.928007
# 1  Online Video  6836809.63  674263903.0  10.139664  10.139664

# %% [markdown]
#  ans : Online Video is more expensive in terms of cpm
